# %%
import pandas as pd

df = pd.read_csv('BigmacPrice.csv')

df.head()
# Out:
#          date currency_code       name  local_price  dollar_ex  dollar_price
# 0  2000-04-01           ARS  Argentina         2.50          1          2.50
# 1  2000-04-01           AUD  Australia         2.59          1          2.59
# 2  2000-04-01           BRL     Brazil         2.95          1          2.95
# 3  2000-04-01           GBP    Britain         1.90          1          1.90
# 4  2000-04-01           CAD     Canada         2.85          1          2.85

# %% [markdown]
# Descrição das colunas
#
# date - Data do registro
#
# currency_code - Código ISO 4217 internacional da moeda do país
#
# name - Nome do país
#
# local_price - Preço do Big Mac na moeda local
#
# dollar_ex - Taxa de Conversão do dólar americano para a moeda local
#
# **local_price** - Preço do Big Mac em dólares americanos

# %%
df.dtypes
# Out:
# date              object
# currency_code     object
# name              object
# local_price      float64
# dollar_ex          int64
# dollar_price     float64
# dtype: object

# %%
df_filtrado = df[df['date'] == '2022-07-01']
df_filtrado.head()
# Out:
#             date currency_code        name  local_price  dollar_ex  \
# 1876  2022-07-01           ARS   Argentina       590.00        129
# 1877  2022-07-01           AUD   Australia         6.70          1
# 1878  2022-07-01           EUR     Austria         4.35          1
# 1879  2022-07-01           AZN  Azerbaijan         4.70          1
# 1880  2022-07-01           BHD     Bahrain         1.60          1
#
#       dollar_price
# 1876          4.57
# 1877          6.70
# 1878          4.35
# 1879          4.70
# 1880          1.60

# %%
df_filtrado.count()
# Out:
# date             70
# currency_code    70
# name             70
# local_price      70
# dollar_ex        70
# dollar_price     70
# dtype: int64

# %%
df_filtrado.groupby('name').count()['date']
# Out:
# name
# Argentina               1
# Australia               1
# Austria                 1
# Azerbaijan              1
# Bahrain                 1
#                        ..
# United Arab Emirates    1
# United States           1
# Uruguay                 1
# Venezuela               1
# Vietnam                 1
# Name: date, Length: 70, dtype: int64

# %%
df_filtrado.to_csv('BigMacPrice_July2022.csv', index = False)

# %%
df = pd.read_csv('BigMacPrice_July2022.csv')
df
# Out:
#           date currency_code                  name  local_price  dollar_ex  \
# 0   2022-07-01           ARS             Argentina       590.00        129
# 1   2022-07-01           AUD             Australia         6.70          1
# 2   2022-07-01           EUR               Austria         4.35          1
# 3   2022-07-01           AZN            Azerbaijan         4.70          1
# 4   2022-07-01           BHD               Bahrain         1.60          1
# ..         ...           ...                   ...          ...        ...
# 65  2022-07-01           AED  United Arab Emirates        18.00          3
# 66  2022-07-01           USD         United States         5.15          1
# 67  2022-07-01           UYU               Uruguay       255.00         41
# 68  2022-07-01           VES             Venezuela        10.00          5
# 69  2022-07-01           VND               Vietnam     69000.00      23417
#
#     dollar_price
# 0           4.57
# 1           6.70
# 2           4.35
# 3           4.70
# 4           1.60
# ..           ...
# 65          6.00
# 66          5.15
# 67          6.22
# 68          2.00
# 69          2.95
#
# [70 rows x 6 columns]

# %% [markdown]
# ###Calculando a moda:

# %%
df['dollar_price'].mode()
# Out:
# 0    4.00
# 1    4.58
# Name: dollar_price, dtype: float64

# %%
df['dollar_price'].value_counts()
# Out:
# 4.58    3
# 4.00    3
# 3.50    2
# 5.67    2
# 3.71    2
#        ..
# 2.85    1
# 2.30    1
# 1.30    1
# 6.70    1
# 2.95    1
# Name: dollar_price, Length: 61, dtype: int64

# %% [markdown]
# ###Calculando a média

# %%
df['dollar_price'].mean()
# Out:
# 4.003571428571429

# %% [markdown]
# ###Calculando a mediana

# %%
df['dollar_price'].median() # Não é influenciada por valores extremos, em contrapartida à média
# Out:
# 3.9050000000000002

# %%
import numpy as np

# %%
np.median(df['dollar_price'])
# Out:
# 3.9050000000000002
